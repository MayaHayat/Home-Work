# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv(r"C:\Users\Maya\Desktop\DataScience\movies_complete.csv")

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                                                           tagline  \
# 0                                                                             NaN
# 1                                       Roll the dice and unleash the excitement!
# 2                            Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#   release_date                    genres           belongs_to_collection  \
# 0   1995-10-30   Animation|Comedy|Family            Toy Story Collection
# 1   1995-12-15  Adventure|Fantasy|Family                             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.hist(figsize = (15, 15), bins = 100)
plt.show()

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %%
df_relevent = df[["title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
df_relevent
# Out:
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# 2                 Grumpier Old Men          NaN           NaN       92.00
# 3                Waiting to Exhale        16.00         81.45       34.00
# 4      Father of the Bride Part II          NaN         76.58      173.00
# ...                            ...          ...           ...         ...
# 44686                       Subdue          NaN           NaN        1.00
# 44687          Century of Birthing          NaN           NaN        3.00
# 44688                     Betrayal          NaN           NaN        6.00
# 44689             Satan Triumphant          NaN           NaN        0.00
# 44690                     Queerama          NaN           NaN        0.00
#
#        vote_average  popularity
# 0              7.70       21.95
# ...

# %%
df_relevent["profit"] = df.revenue_musd.sub(df.budget_musd)
df_relevent["ROI"] = df.revenue_musd.div(df.budget_musd)

df_relevent
# Out:
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# 2                 Grumpier Old Men          NaN           NaN       92.00
# 3                Waiting to Exhale        16.00         81.45       34.00
# 4      Father of the Bride Part II          NaN         76.58      173.00
# ...                            ...          ...           ...         ...
# 44686                       Subdue          NaN           NaN        1.00
# 44687          Century of Birthing          NaN           NaN        3.00
# 44688                     Betrayal          NaN           NaN        6.00
# 44689             Satan Triumphant          NaN           NaN        0.00
# 44690                     Queerama          NaN           NaN        0.00
#
#        vote_average  popularity  profit  return   ROI
# ...

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df_relevent.sort_values(by='revenue_musd', ascending=False).head()
# Out:
#                               title  budget_musd  revenue_musd  vote_count  \
# 14448                        Avatar       237.00       2787.97    12114.00
# 26265  Star Wars: The Force Awakens       245.00       2068.22     7993.00
# 1620                        Titanic       200.00       1845.03     7770.00
# 17669                  The Avengers       220.00       1519.56    12000.00
# 24812                Jurassic World       150.00       1513.53     8842.00
#
#        vote_average  popularity  profit  return   ROI
# 14448          7.20      185.07 2550.97   11.76 11.76
# 26265          7.50       31.63 1823.22    8.44  8.44
# 1620           7.50       26.89 1645.03    9.23  9.23
# 17669          7.40       89.89 1299.56    6.91  6.91
# 24812          6.50       32.79 1363.53   10.09 10.09

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df_relevent.sort_values(by='budget_musd', ascending=False).head()
# Out:
#                                              title  budget_musd  revenue_musd  \
# 16986  Pirates of the Caribbean: On Stranger Tides       380.00       1045.71
# 11743     Pirates of the Caribbean: At World's End       300.00        961.00
# 26268                      Avengers: Age of Ultron       280.00       1405.40
# 10985                             Superman Returns       270.00        391.08
# 18517                                  John Carter       260.00        284.14
#
#        vote_count  vote_average  popularity  profit  return  ROI
# 16986     5068.00          6.40       27.89  665.71    2.75 2.75
# 11743     4627.00          6.90       31.36  661.00    3.20 3.20
# 26268     6908.00          7.30       37.38 1125.40    5.02 5.02
# 10985     1429.00          5.40       13.28  121.08    1.45 1.45
# 18517     2170.00          6.10       14.67   24.14    1.09 1.09

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df_relevent.sort_values(by='profit', ascending=False).head()
# Out:
#                               title  budget_musd  revenue_musd  vote_count  \
# 14448                        Avatar       237.00       2787.97    12114.00
# 26265  Star Wars: The Force Awakens       245.00       2068.22     7993.00
# 1620                        Titanic       200.00       1845.03     7770.00
# 24812                Jurassic World       150.00       1513.53     8842.00
# 28501                     Furious 7       190.00       1506.25     4253.00
#
#        vote_average  popularity  profit  return   ROI
# 14448          7.20      185.07 2550.97   11.76 11.76
# 26265          7.50       31.63 1823.22    8.44  8.44
# 1620           7.50       26.89 1645.03    9.23  9.23
# 24812          6.50       32.79 1363.53   10.09 10.09
# 28501          7.30       27.28 1316.25    7.93  7.93

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df_relevent.sort_values(by='profit', ascending=True).head()
# Out:
#                                              title  budget_musd  revenue_musd  \
# 20959                              The Lone Ranger       255.00         89.29
# 7164                                     The Alamo       145.00         25.82
# 16659                              Mars Needs Moms       150.00         38.99
# 43611  Valerian and the City of a Thousand Planets       197.47         90.02
# 2684                              The 13th Warrior       160.00         61.70
#
#        vote_count  vote_average  popularity  profit  return  ROI
# 20959     2361.00          5.90       12.73 -165.71    0.35 0.35
# 7164       108.00          5.80       12.24 -119.18    0.18 0.18
# 16659      202.00          5.60        7.25 -111.01    0.26 0.26
# 43611      905.00          6.70       15.26 -107.45    0.46 0.46
# 2684       524.00          6.40       10.31  -98.30    0.39 0.39

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df_relevent.sort_values(by='ROI', ascending=False).head()
# Out:
#                          title  budget_musd  revenue_musd  vote_count  \
# 3965            Less Than Zero         0.00         12.40       77.00
# 3312              Modern Times         0.00          8.50      881.00
# 14270    Welcome to Dongmakgol         0.00         33.58       49.00
# 22041           Aquí Entre Nos         0.00          2.76        3.00
# 2284   The Karate Kid, Part II         0.00        115.10      457.00
#
#        vote_average  popularity  profit      return         ROI
# 3965           6.10        4.03   12.40 12396383.00 12396383.00
# 3312           8.10        8.16    8.50  8500000.00  8500000.00
# 14270          7.70        4.22   33.58  4197476.62  4197476.62
# 22041          6.00        0.23    2.76  2755584.00  2755584.00
# 2284           5.90        9.23  115.10  1018619.28  1018619.28

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df_relevent.sort_values(by='ROI', ascending=True).head()
# Out:
#                          title  budget_musd  revenue_musd  vote_count  \
# 6955           Chasing Liberty        23.00          0.00      154.00
# 8041               The Cookout        16.00          0.00       10.00
# 2636   Never Talk to Strangers         6.40          0.00       31.00
# 12859           To Rob a Thief         4.00          0.00        4.00
# 17381                 Deadfall        10.00          0.00       14.00
#
#        vote_average  popularity  profit  return  ROI
# 6955           6.10        5.95  -23.00    0.00 0.00
# 8041           4.60        1.76  -16.00    0.00 0.00
# 2636           4.70        7.51   -6.40    0.00 0.00
# 12859          6.00        1.02   -4.00    0.00 0.00
# 17381          3.10        1.15  -10.00    0.00 0.00

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df_relevent.sort_values(by='vote_count', ascending=False).head()
# Out:
#                  title  budget_musd  revenue_musd  vote_count  vote_average  \
# 15368        Inception       160.00        825.53    14075.00          8.10
# 12396  The Dark Knight       185.00       1004.56    12269.00          8.30
# 14448           Avatar       237.00       2787.97    12114.00          7.20
# 17669     The Avengers       220.00       1519.56    12000.00          7.40
# 26272         Deadpool        58.00        783.11    11444.00          7.40
#
#        popularity  profit  return   ROI
# 15368       29.11  665.53    5.16  5.16
# 12396      123.17  819.56    5.43  5.43
# 14448      185.07 2550.97   11.76 11.76
# 17669       89.89 1299.56    6.91  6.91
# 26272      187.86  725.11   13.50 13.50

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df_relevent.sort_values(by='vote_average', ascending=False).head()
# Out:
#                                             title  budget_musd  revenue_musd  \
# 36996  Portrait of a Young Man in Three Movements          NaN           NaN
# 33891                         Brave Revolutionary          NaN           NaN
# 1615                     Other Voices Other Rooms          NaN           NaN
# 35505                          The Lion of Thebes          NaN           NaN
# 25882         Katt Williams: Priceless: Afterlife          NaN           NaN
#
#        vote_count  vote_average  popularity  profit  return  ROI
# 36996        1.00         10.00        0.04     NaN     NaN  NaN
# 33891        1.00         10.00        0.32     NaN     NaN  NaN
# 1615         1.00         10.00        0.04     NaN     NaN  NaN
# 35505        1.00         10.00        1.78     NaN     NaN  NaN
# 25882        2.00         10.00        0.48     NaN     NaN  NaN

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df_relevent.sort_values(by='vote_average', ascending=True).head()
# Out:
#                                              title  budget_musd  revenue_musd  \
# 24522                          Dance, Fools, Dance          NaN           NaN
# 37762  .hack Liminality: In the Case of Mai Minase          NaN           NaN
# 26403                              Lucrezia Borgia          NaN           NaN
# 12189                                  Joe and Max         8.00           NaN
# 20450                               The Substitute          NaN           NaN
#
#        vote_count  vote_average  popularity  profit  return  ROI
# 24522        2.00          0.00        2.03     NaN     NaN  NaN
# 37762        1.00          0.00        0.09     NaN     NaN  NaN
# 26403        2.00          0.00        0.14     NaN     NaN  NaN
# 12189        1.00          0.00        1.67     NaN     NaN  NaN
# 20450        1.00          0.00        0.68     NaN     NaN  NaN

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df_relevent.sort_values(by='popularity', ascending=False).head()
# Out:
#                       title  budget_musd  revenue_musd  vote_count  \
# 30330               Minions        74.00       1156.73     4729.00
# 32927          Wonder Woman       149.00        820.58     5025.00
# 41556  Beauty and the Beast       160.00       1262.89     5530.00
# 42940           Baby Driver        34.00        224.51     2083.00
# 24187            Big Hero 6       165.00        652.11     6289.00
#
#        vote_average  popularity  profit  return   ROI
# 30330          6.40      547.49 1082.73   15.63 15.63
# 32927          7.20      294.34  671.58    5.51  5.51
# 41556          6.80      287.25 1102.89    7.89  7.89
# 42940          7.20      228.03  190.51    6.60  6.60
# 24187          7.80      213.85  487.11    3.95  3.95

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")

# %%
df_actor = df.cast.str.contains("Bruce Willis")

# %%
df.loc[df_actor & df_genres, ["title", "vote_average"]].sort_values(by = "vote_average", 
                                                                        ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
df_director = df.director == "Quentin Tarantino"

# %%
df_actor = df.cast.str.contains("Uma Thurman")

# %%
df.loc[df_director & df_actor,["title", "runtime"]].sort_values(by = "runtime").set_index("title")
# Out:
#                    runtime
# title
# Kill Bill: Vol. 1   111.00
# Kill Bill: Vol. 2   136.00
# Pulp Fiction        154.00

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
df_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
df_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
df.loc[df_studio & df_time, 
               ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by = "revenue_musd", ascending = False).set_index("title")
# Out:
#                                                                                                                   poster_path  \
# title
# Toy Story 3                 <img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'>
# Inside Out                  <img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'>
# Monsters University         <img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'>
# Cars 2                      <img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'>
# Brave                       <img src='http://image.tmdb.org/t/p/w185//8l0pzWBrStFtbZiqeu0cGhxGKkT.jpg' style='height:100px;'>
# The Good Dinosaur           <img src='http://image.tmdb.org/t/p/w185//8RSkxOO80btfKjyiC5ZiTaCHIT8.jpg' style='height:100px;'>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
df_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")

# %%
df_english = df.original_language == "en"

# %%
df_vote_av = df.vote_average >= 7.5

# %%
df.loc[df_genre & df_english & df_vote_av, 
               ["title", "genres", "vote_average", "release_date"]].sort_values(by = "release_date", ascending = False).set_index("title").head(20)
# Out:
#                                                                        genres  \
# title
# Descendants 2                   TV Movie|Family|Action|Comedy|Music|Adventure
# Dunkirk                                     Action|Drama|History|Thriller|War
# The Book of Henry                                        Thriller|Drama|Crime
# Guardians of the Galaxy Vol. 2        Action|Adventure|Comedy|Science Fiction
# Revengeance                                           Comedy|Action|Animation
# First Round Down                                                Action|Comedy
# Logan                                            Action|Drama|Science Fiction
# Tomato Red                                                     Drama|Thriller
# Zero 3                                                               Thriller
# The River Thief                                        Crime|Action|Adventure
# The Thinning                                                         Thriller
# ...

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %%
df["Franchise"] = df.belongs_to_collection.notna()

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby("Franchise").revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise").budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise").popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise").vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                              29
# Totò Collection                              27
# James Bond Collection                        26
# Zatôichi: The Blind Swordsman                26
# The Carry On Collection                      25
#                                              ..
# Public Enemy Series                           1
# Golgo 13 Collection                           1
# Täällä Pohjantähden alla (Timo Koivusalo)     1
# Yamla Pagla Deewana                           1
# Bang Rajan Collection                         1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum", "mean"], 
                                                      "revenue_musd": ["sum", "mean"],
                                                      "vote_average": "mean", "popularity": "mean",
                                                      "ROI":"median", 
                                                      "vote_count":"mean"})

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Tangled Collection                          2      260.00 260.00       591.79
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Avengers Collection                     2      500.00 250.00      2924.96
# The Hobbit Collection                       3      750.00 250.00      2935.52
# Man of Steel Collection                     2      475.00 237.50      1536.11
# Avatar Collection                           1      237.00 237.00      2787.97
# The Amazing Spider-Man Collection           2      415.00 207.50      1457.93
# World War Z Collection                      1      200.00 200.00       531.87
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# ...

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00 150.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  74.75      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
franchises.nlargest(20, ("vote_count", "mean"))
# Out:
#                                    title budget_musd        revenue_musd  \
#                                    count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                      1      237.00 237.00      2787.97
# Deadpool Collection                    1       58.00  58.00       783.11
# The Dark Knight Collection             3      585.00 195.00      2463.72
# The Avengers Collection                2      500.00 250.00      2924.96
# Iron Man Collection                    3      540.00 180.00      2424.55
# The Lord of the Rings Collection       3      266.00  88.67      2916.54
# Guardians of the Galaxy Collection     2      370.00 185.00      1636.74
# Captain America Collection             3      560.00 186.67      2238.64
# Man of Steel Collection                2      475.00 237.50      1536.11
# The Hunger Games Collection            4      490.00 122.50      2944.16
# ...

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.director.value_counts().head()
# Out:
# John Ford           66
# Michael Curtiz      65
# Werner Herzog       54
# Alfred Hitchcock    53
# Georges Méliès      49
# Name: director, dtype: int64

# %%
df.groupby("director").revenue_musd.sum().nlargest()
# Out:
# director
# Steven Spielberg   9256.62
# Peter Jackson      6528.24
# Michael Bay        6437.47
# James Cameron      5900.61
# David Yates        5334.56
# Name: revenue_musd, dtype: float64

# %%
df.groupby("director").popularity.sum().nlargest()
# Out:
# director
# Kyle Balda         602.43
# Ridley Scott       436.91
# Steven Spielberg   429.59
# Bill Condon        395.72
# Woody Allen        376.00
# Name: popularity, dtype: float64
